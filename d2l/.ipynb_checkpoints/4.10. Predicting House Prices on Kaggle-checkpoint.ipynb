# %%
# %matplotlib inline
import torch as tc
import tensorflow as tf
import mxnet as mx
from mxnet import np as mxnp
from mxnet import npx as npx
npx.set_np()
import numpy as np

from d2l import mxnet as mxd2l  # Use MXNet as the backend
from d2l import torch as tcd2l  # Use PyTorch as the backend
from d2l import tensorflow as tfd2l  # Use TensorFlow as the backend

from d2l import mxnet as mxd2l  # Use MXNet as the backend
from d2l import torch as tcd2l  # Use PyTorch as the backend
from d2l import tensorflow as tfd2l  # Use TensorFlow as the backend

tc.__version__,tf.__version__,mx.__version__
# Out:
# ('1.6.0', '2.3.1', '1.7.0')

# %%
train_file=r'..\data\kaggle_house_pred_train.csv'
test_file=r'..\data\kaggle_house_pred_test.csv'

# %%
import pandas as pd

# %%
train_data=pd.read_csv(train_file)
test_data=pd.read_csv(test_file)

# %%
train_data.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
test_data.head(2)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
#
# [2 rows x 80 columns]

# %%
train_data.shape,test_data.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
train_data.iloc[0:4,[1,2,3,4,-3,-2,-1]]
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea SaleType SaleCondition  SalePrice
# 0          60       RL         65.0     8450       WD        Normal     208500
# 1          20       RL         80.0     9600       WD        Normal     181500
# 2          60       RL         68.0    11250       WD        Normal     223500
# 3          70       RL         60.0     9550       WD       Abnorml     140000

# %%
all_features=pd.concat((train_data.iloc[:,1:-1],test_data.iloc[:,1:]))

# %%
all_features.shape
# Out:
# (2919, 79)

# %%
type(all_features.dtypes)
# Out:
# pandas.core.series.Series

# %%
all_features.dtypes[0]
# Out:
# dtype('int64')

# %%
numeric_features=all_features.dtypes[all_features.dtypes!='object'].index

# %%
numeric_features
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
all_features.dtypes!='object'
# Out:
# MSSubClass        True
# MSZoning         False
# LotFrontage       True
# LotArea           True
# Street           False
#                  ...
# MiscVal           True
# MoSold            True
# YrSold            True
# SaleType         False
# SaleCondition    False
# Length: 79, dtype: bool

# %%
all_features.dtypes[all_features.dtypes!='object']
# Out:
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# dtype: object

# %%
type(all_features.dtypes[all_features.dtypes!='object'])
# Out:
# pandas.core.series.Series

# %%
all_features.dtypes[all_features.dtypes!='object'].index
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
# all_features.dtypes[all_features.dtypes!='object'].index

# %%
type(all_features.dtypes[all_features.dtypes!='object'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
# pd.core.indexes.base.Index??

# %%
numeric_features
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
all_features[numeric_features]=all_features[numeric_features].apply(lambda x:(x-x.mean())/x.std())

# %%
all_features[numeric_features].head(2)
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.067320    -0.184443 -0.217841     0.646073    -0.507197   1.046078
# 1   -0.873466     0.458096 -0.072032    -0.063174     2.187904   0.154737
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0      0.896679    0.523038    0.580708    -0.29303  ...    0.348780
# 1     -0.395536   -0.569893    1.177709    -0.29303  ...   -0.059772
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0   -0.740634     0.199972      -0.359539  -0.103313    -0.285886 -0.063139
# 1    1.614603    -0.702722      -0.359539  -0.103313    -0.285886 -0.063139
#
#     MiscVal    MoSold    YrSold
# 0 -0.089577 -1.551918  0.157619
# 1 -0.089577 -0.446848 -0.602858
#
# [2 rows x 36 columns]

# %%
all_features[numeric_features]=all_features[numeric_features].fillna(0.0)

# %%
all_features.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0    0.067320       RL    -0.184443 -0.217841   Pave   NaN      Reg
# 1   -0.873466       RL     0.458096 -0.072032   Pave   NaN      Reg
# 2    0.067320       RL    -0.055935  0.137173   Pave   NaN      IR1
# 3    0.302516       RL    -0.398622 -0.078371   Pave   NaN      IR1
# 4    0.067320       RL     0.629439  0.518814   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch  PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...   -0.285886 -0.063139    NaN   NaN
# 1         Lvl    AllPub       FR2  ...   -0.285886 -0.063139    NaN   NaN
# 2         Lvl    AllPub    Inside  ...   -0.285886 -0.063139    NaN   NaN
# 3         Lvl    AllPub    Corner  ...   -0.285886 -0.063139    NaN   NaN
# 4         Lvl    AllPub       FR2  ...   -0.285886 -0.063139    NaN   NaN
#
#   MiscFeature   MiscVal    MoSold    YrSold  SaleType  SaleCondition
# ...

# %%
all_features=pd.get_dummies(all_features,dummy_na=True)

# %%
all_features.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.067320    -0.184443 -0.217841     0.646073    -0.507197   1.046078
# 1   -0.873466     0.458096 -0.072032    -0.063174     2.187904   0.154737
# 2    0.067320    -0.055935  0.137173     0.646073    -0.507197   0.980053
# 3    0.302516    -0.398622 -0.078371     0.646073    -0.507197  -1.859033
# 4    0.067320     0.629439  0.518814     1.355319    -0.507197   0.947040
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_Oth  \
# 0      0.896679    0.523038    0.580708    -0.29303  ...             0
# 1     -0.395536   -0.569893    1.177709    -0.29303  ...             0
# 2      0.848819    0.333448    0.097840    -0.29303  ...             0
# 3     -0.682695   -0.569893   -0.494771    -0.29303  ...             0
# 4      0.753100    1.381770    0.468770    -0.29303  ...             0
#
#    SaleType_WD  SaleType_nan  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# ...

# %%
all_features.shape
# Out:
# (2919, 331)

# %%
n_train = train_data.shape[0];n_test=len(test_data)
n_train,n_test,n_train+n_test
# Out:
# (1460, 1459, 2919)

# %% [markdown]
# ## dataset of type numpy.array

# %%
train_features=np.array(all_features[:n_train].values,dtype=mxnp.float32)
train_labels = np.array(train_data.SalePrice.values.reshape(-1, 1), dtype=np.float32)
test_features =np.array(all_features[n_train:].values,dtype=mxnp.float32)

# %%
# all_features.head(1).values

# %%
train_features.shape,test_features.shape,train_labels.shape
# Out:
# ((1460, 331), (1459, 331), (1460, 1))

# %%
type(train_features),type(test_features)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# ### --mx data

# %%
train_features_mx=mxnp.array(train_features);test_features_mx=mxnp.array(test_features)
train_labels_mx  =mxnp.array(train_labels)

# %%
type(train_features_mx),type(test_features_mx),type(train_labels_mx)
# Out:
# (mxnet.numpy.ndarray, mxnet.numpy.ndarray, mxnet.numpy.ndarray)

# %%
train_features_mx.shape,train_labels_mx.shape,test_features_mx.shape
# Out:
# ((1460, 331), (1460, 1), (1459, 331))

# %% [markdown]
# ### -mx models

# %%
from mxnet import gluon
from mxnet.gluon import nn
from mxnet import autograd

# %%
loss=gluon.loss.L2Loss()

# %%
def log_rmse(net,features,labels):
    # To further stabilize the value when the logarithm is taken, set the
    # value less than 1 as 1
    clipped_preds=mxnp.clip(net(features),1.0,float("inf"))
    return mxnp.sqrt(2*loss(mxnp.log(clipped_preds),mxnp.log(labels)).mean())

# %%
def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(1))
    net.initialize()
    return net

# %%
net=get_net()

# %%
y_hat=net(test_features_mx[0:10])

# %%
y_hat.shape
# Out:
# (10, 1)

# %%
y_hat
# Out:
# array([[ 0.52869624],
#        [-0.35833868],
#        [-0.01882416],
#        [ 0.09284887],
#        [ 0.10068028],
#        [ 0.05930321],
#        [ 0.5100959 ],
#        [-0.05578984],
#        [ 0.31142133],
#        [ 0.47859088]])

# %%
log_rmse(net,train_features_mx[0:10],train_labels_mx[0:10])
# Out:
# array(12.115272)

# %%
import pdb

# %%
def train(net,train_features,train_labels,test_features,test_labels,num_epochs,learning_rate,weight_decay,batch_size):
    train_losses,test_losses=[],[]
    train_iter=mxd2l.load_array((train_features,train_labels),batch_size)
#     print(f"train_iter type:{type(train_iter)},len(train_iter):{len(train_iter)}")
    trainer=gluon.Trainer(net.collect_params(),'adam',{"learning_rate":learning_rate,'wd':weight_decay})
    for epoch in range(num_epochs):
#         pdb.set_trace()
        for X,y in train_iter:
#             print(f"X type:{type(X)},y type:{type(y)}")
#             print(f"X shape:{X.shape},y shape:{y.shape}")
            
            with autograd.record():
                l=loss(net(X),y)
            l.backward()
            trainer.step(batch_size)
        train_losses.append(log_rmse(net,train_features,train_labels))
        if test_labels is not None:
            test_losses.append(log_rmse(net,test_features,test_labels))
    return train_losses,test_losses

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid, y_valid = X_part, y_part
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = mxnp.concatenate([X_train, X_part], 0)
            y_train = mxnp.concatenate([y_train, y_part], 0)
#     print(f"IN get_k_fold_data: X_train type:{type(X_train)},y_train type:{type(y_train)}")
#     print(f"IN get_k_fold_data: X_train.shape:{X_train.shape},y_train type:{y_train.shape}")
    return X_train, y_train, X_valid, y_valid

# %%
def k_fold(k, X_train, y_train, num_epochs, learning_rate, weight_decay,batch_size,d2l=mxd2l):
#     print(f"IN k_fold: X_train type:{type(X_train)},y_train type:{type(y_train)}")
#     print(f"IN k_fold: X_train.shape:{X_train.shape},y_train type:{y_train.shape}")
#     train_features_mx.shape, train_labels_mx.shape
    train_l_sum, valid_l_sum = 0, 0
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        
        net = get_net()
        train_ls, valid_ls = train(net, *data, num_epochs, learning_rate,
                                   weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        valid_l_sum += valid_ls[-1]
        if i == 0:
            d2l.plot(list(range(1, num_epochs + 1)), [train_ls, valid_ls],
                     xlabel='epoch', ylabel='rmse', xlim=[1, num_epochs],
                     legend=['train', 'valid'], yscale='log')
        print(f'fold {i + 1}, train log rmse {float(train_ls[-1]):f}, '
              f'valid log rmse {float(valid_ls[-1]):f}')
    return train_l_sum / k, valid_l_sum / k

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 100, 5, 0, 64
train_l, valid_l = k_fold(k, train_features_mx, train_labels_mx, num_epochs, lr,weight_decay, batch_size)
print(f'{k}-fold validation: avg train log rmse: {float(train_l):f}, '
      f'avg valid log rmse: {float(valid_l):f}')
# Out:
# fold 1, train log rmse 0.169496, valid log rmse 0.156892
# fold 2, train log rmse 0.162084, valid log rmse 0.189193
# fold 3, train log rmse 0.163509, valid log rmse 0.167752
# fold 4, train log rmse 0.167763, valid log rmse 0.154717
# fold 5, train log rmse 0.162879, valid log rmse 0.183081
# 5-fold validation: avg train log rmse: 0.165146, avg valid log rmse: 0.170327

# %%
train_features_mx.shape, train_labels_mx.shape
# Out:
# ((1460, 331), (1460, 1))

# %%
type(train_features_mx)
# Out:
# mxnet.numpy.ndarray

# %%
train_iter=mxd2l.load_array((train_features_mx,train_labels_mx),batch_size)

# %%
X,y=next(iter(train_iter))

# %%
X.shape,y.shape
# Out:
# ((64, 331), (64, 1))

# %%
for X,y in train_iter:
    print(f"X type:{type(X)},y type:{type(y)}")
    print(f"X type:{X.shape},y type:{y.shape}")
    break
# Out:
# X type:<class 'mxnet.numpy.ndarray'>,y type:<class 'mxnet.numpy.ndarray'>
# X type:(64, 331),y type:(64, 1)

# %%
len(train_iter)
# Out:
# 23

# %%
def train_and_pred(train_features, test_features, train_labels, test_data,
                   num_epochs, lr, weight_decay, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None,
                        num_epochs, lr, weight_decay, batch_size)
    mxd2l.plot(np.arange(1, num_epochs + 1), [train_ls], xlabel='epoch',
             ylabel='log rmse', xlim=[1, num_epochs], yscale='log')
    print(f'train log rmse {float(train_ls[-1]):f}')
    # Apply the network to the test set
    preds = mxd2l.numpy(net(test_features))
    # Reformat it to export to Kaggle
    test_data['SalePrice'] = pd.Series(preds.reshape(1, -1)[0])
    submission = pd.concat([test_data['Id'], test_data['SalePrice']], axis=1)
    submission.to_csv('submission.csv', index=False)

# %%
train_and_pred(train_features_mx, test_features_mx, train_labels_mx, test_data,num_epochs, lr, weight_decay, batch_size)
# Out:
# train log rmse 0.162689

# %%
type(test_features_mx)
# Out:
# mxnet.numpy.ndarray

# %%
l=[train_features_mx, test_features_mx, train_labels_mx, test_data]

# %%
for i in l:
    print(type(i),i.shape)
# Out:
# <class 'mxnet.numpy.ndarray'> (1460, 331)
# <class 'mxnet.numpy.ndarray'> (1459, 331)
# <class 'mxnet.numpy.ndarray'> (1460, 1)
# <class 'pandas.core.frame.DataFrame'> (1459, 80)
